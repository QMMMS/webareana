# %%
# 读取 /home/zjusst/qms/persona-hub/data/elite_personas.part1.jsonl 的前100行，注意不要读取整个文件
import json

lines = []
with open('/home/zjusst/qms/persona-hub/data/elite_personas.part1.jsonl', 'r') as f:
    for _ in range(10000):  # 替换 5 为你需要的行数
        line = next(f)
        lines.append(line)

# 写入 /home/zjusst/qms/persona-hub/data/elite_personas_10000.jsonl
with open('/home/zjusst/qms/persona-hub/data/elite_personas_10000.jsonl', 'w') as f:
    for line in lines:
        f.write(line)

# %%
from datasets import load_dataset

import os


# os.environ['HTTP_PROXY'] = 'http://127.0.0.1:7890'
# os.environ['HTTPS_PROXY'] = 'http://127.0.0.1:7890'

# Login using e.g. `huggingface-cli login` to access this dataset
# ds = load_dataset("proj-persona/PersonaHub", "elite_persona")
# ds = load_dataset("proj-persona/PersonaHub", "persona")
# /home/zjusst/.cache/huggingface/hub/datasets--proj-persona--PersonaHub/snapshots/16777e34bf5cb758b925cae5d84e868ee6c2100c

# %%
ds["train"][0]
# Out:
# {'persona': "A Political Analyst specialized in El Salvador's political landscape."}
